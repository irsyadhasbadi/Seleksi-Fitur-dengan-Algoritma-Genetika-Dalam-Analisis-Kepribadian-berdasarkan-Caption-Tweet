# %%
import json
import pandas as pd
import random
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
import joblib
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV, StratifiedKFold

# %%
df = pd.read_csv('Data_Train.csv')
df.head()
# Out:
#                                            full_text     username  MBTI IE NS  \
# 0  masih about my wedding makeup kali ini makeup ...  DylanSahara  ENFJ  E  N
# 1  terima kasih kepada bapak prabowo subianto yan...  DylanSahara  ENFJ  E  N
# 2                          halo calon suami hahahaha  DylanSahara  ENFJ  E  N
# 3  muka dicoretcoret pakai kostum kayak orang gil...  DylanSahara  ENFJ  E  N
# 4       saat muka masih cakep belum dicemongcemongin  DylanSahara  ENFJ  E  N
#
#   TF JP
# 0  F  J
# 1  F  J
# 2  F  J
# 3  F  J
# 4  F  J

# %%
df.shape
# Out:
# (9350, 7)

# %%
df.username.value_counts()
# Out:
# username
# DylanSahara        50
# RickyHarun45MF     50
# NRamadhani         50
# morganoey          50
# Haruka_NKGW10      50
#                    ..
# titokarnavian_     50
# budimandjatmiko    50
# Freya_JKT48        50
# L_MarshaJKT48      50
# chelseaislan       50
# Name: count, Length: 187, dtype: int64

# %%
df.username.nunique()
# Out:
# 187

# %%
# Ubah label IE ke format biner
df['IE_bin'] = df['IE'].apply(lambda x: 1 if x == 'I' else 0)
df['NS_bin'] = df['NS'].apply(lambda x: 1 if x == 'N' else 0)
df['TF_bin'] = df['TF'].apply(lambda x: 1 if x == 'T' else 0)
df['JP_bin'] = df['JP'].apply(lambda x: 1 if x == 'J' else 0)

# %%
df.head()
# Out:
#                                            full_text     username  MBTI IE NS  \
# 0  masih about my wedding makeup kali ini makeup ...  DylanSahara  ENFJ  E  N
# 1  terima kasih kepada bapak prabowo subianto yan...  DylanSahara  ENFJ  E  N
# 2                          halo calon suami hahahaha  DylanSahara  ENFJ  E  N
# 3  muka dicoretcoret pakai kostum kayak orang gil...  DylanSahara  ENFJ  E  N
# 4       saat muka masih cakep belum dicemongcemongin  DylanSahara  ENFJ  E  N
#
#   TF JP  IE_bin  NS_bin  TF_bin  JP_bin
# 0  F  J       0       1       0       1
# 1  F  J       0       1       0       1
# 2  F  J       0       1       0       1
# 3  F  J       0       1       0       1
# 4  F  J       0       1       0       1

# %%
df_test = pd.read_csv('Data_Test.csv')

# %%
df_test.head()
# Out:
#                                            full_text      username  MBTI IE  \
# 0                                      lah bagaimana  bismakarisma  ISFJ  I
# 1                                       uji coba yok  bismakarisma  ISFJ  I
# 2  ngeri antusiasku bisa sampai belum tidur gini ...  bismakarisma  ISFJ  I
# 3  aduh ini badut romantis yang selalu romantis l...  bismakarisma  ISFJ  I
# 4                                   lop yu dari sagi  bismakarisma  ISFJ  I
#
#   NS TF JP
# 0  S  F  J
# 1  S  F  J
# 2  S  F  J
# 3  S  F  J
# 4  S  F  J

# %%
df_test.shape
# Out:
# (2300, 7)

# %%
df_test.username.value_counts()
# Out:
# username
# bismakarisma       50
# itsPrisia          50
# amandamanopo       50
# yukikato           50
# alfiealfandy       50
# alicesofieNORIN    50
# omeshomesh         50
# wikanarif          50
# TitiRadjoPdmaja    50
# shenacinnamon      50
# ronniesianturi     50
# annekejd           50
# AndovidaLopez      50
# auliasarah69       50
# ayukhadijahazha    50
# ralineshah         50
# Bellaudyaa         50
# jonasrivanno       50
# kvinjulio          50
# kinaryosih_03      50
# desyratnasari      50
# Donny_Alamsyah     50
# bobbynasution_     50
# danillajpr         50
# Dodit_Mulyanto     50
# RFritzy_JKT48      50
# kikysaputrii       50
# nessiejudge        50
# ekagustiwana       50
# CoachJustinL       50
# ernestprakasa      50
# Arie_Kriting       50
# suryainsomnia      50
# ArnoldPoernomo     50
# TretanMuslim       50
# LunaMaya26         50
# brisiajodie96      50
# jokowi             50
# felixsiauw         50
# tirta_cipeng       50
# aniesbaswedan      50
# erickthohir        50
# tulusm             50
# A_FionyJKT48       50
# _shanindira        50
# uusbiasaaja        50
# Name: count, dtype: int64

# %%
df_test.username.nunique()
# Out:
# 46

# %%
# Ubah label IE ke format biner
df_test['IE_bin'] = df_test['IE'].apply(lambda x: 1 if x == 'I' else 0)
df_test['NS_bin'] = df_test['NS'].apply(lambda x: 1 if x == 'N' else 0)
df_test['TF_bin'] = df_test['TF'].apply(lambda x: 1 if x == 'T' else 0)
df_test['JP_bin'] = df_test['JP'].apply(lambda x: 1 if x == 'J' else 0)

# %%
df_test.head()
# Out:
#                                            full_text      username  MBTI IE  \
# 0                                      lah bagaimana  bismakarisma  ISFJ  I
# 1                                       uji coba yok  bismakarisma  ISFJ  I
# 2  ngeri antusiasku bisa sampai belum tidur gini ...  bismakarisma  ISFJ  I
# 3  aduh ini badut romantis yang selalu romantis l...  bismakarisma  ISFJ  I
# 4                                   lop yu dari sagi  bismakarisma  ISFJ  I
#
#   NS TF JP  IE_bin  NS_bin  TF_bin  JP_bin
# 0  S  F  J       1       0       0       1
# 1  S  F  J       1       0       0       1
# 2  S  F  J       1       0       0       1
# 3  S  F  J       1       0       0       1
# 4  S  F  J       1       0       0       1

# %%
X_test, y_test = df_test["full_text"], df_test[["IE_bin", "NS_bin", "TF_bin", "JP_bin"]]

X_test_vec = vectorizer.transform(X_test)

# %%
# Membuat TF-IDF vectorizer
texts = df['full_text']
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(texts)
y = df[['IE_bin', 'NS_bin', 'TF_bin', 'JP_bin']]

# %%
# Inisialisasi K-Fold
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
all_class_reports = []
# Menyimpan model terbaik dari setiap label
best_models = {}
label_list = ['IE_bin', 'NS_bin', 'TF_bin', 'JP_bin']
all_best_model_reports = []

for label in label_list:
    print(f"\nTraining SVM untuk label {label} dengan K-Fold...")
    best_score = 0
    best_model = None
    best_report = None
    fold_num = 1

    for train_index, val_index in kf.split(X, y[label]):
        X_train_fold, X_val_fold = X[train_index], X[val_index]
        y_train_fold = y[label].iloc[train_index]
        y_val_fold = y[label].iloc[val_index]

        model = SVC(C=10, gamma='scale', kernel='rbf')
        model.fit(X_train_fold, y_train_fold)

        y_pred = model.predict(X_val_fold)
        report = classification_report(y_val_fold, y_pred, output_dict=True)
        f1 = report['weighted avg']['f1-score']
        print(f"Fold {fold_num} - F1 Score: {f1:.4f}")
        fold_num += 1

        if f1 > best_score:
            best_score = f1
            best_model = model
            best_report = report

    # Simpan model terbaik
    best_models[label] = best_model
    joblib.dump(best_model, f'{label}_svm_best_kfold.pkl')

    # Simpan laporan performa
    for kelas in ['0', '1']:
        if kelas in best_report:
            precision = best_report[kelas]['precision']
            recall = best_report[kelas]['recall']
            f1_score_kelas = best_report[kelas]['f1-score']
        else:
            precision = recall = f1_score_kelas = 0.0

        all_best_model_reports.append({
            'Label': label,
            'Kelas': kelas,
            'Precision': round(precision, 3),
            'Recall': round(recall, 3),
            'F1_Score': round(f1_score_kelas, 3),
            'Accuracy': round(best_report['accuracy'], 3)
        })
# Out:
# Training SVM untuk label IE_bin dengan K-Fold...
# Fold 1 - F1 Score: 0.6453
# Fold 2 - F1 Score: 0.6493
# Fold 3 - F1 Score: 0.6344
# Fold 4 - F1 Score: 0.6622
# Fold 5 - F1 Score: 0.6512
#
# Training SVM untuk label NS_bin dengan K-Fold...
# Fold 1 - F1 Score: 0.6538
# Fold 2 - F1 Score: 0.6371
# Fold 3 - F1 Score: 0.6354
# Fold 4 - F1 Score: 0.6432
# Fold 5 - F1 Score: 0.6382
#
# Training SVM untuk label TF_bin dengan K-Fold...
# Fold 1 - F1 Score: 0.6971
# Fold 2 - F1 Score: 0.7048
# Fold 3 - F1 Score: 0.6818
# Fold 4 - F1 Score: 0.6797
# Fold 5 - F1 Score: 0.6850
#
# Training SVM untuk label JP_bin dengan K-Fold...
# Fold 1 - F1 Score: 0.6481
# Fold 2 - F1 Score: 0.6724
# Fold 3 - F1 Score: 0.6659
# Fold 4 - F1 Score: 0.6605
# Fold 5 - F1 Score: 0.6497

# %%
df_all_class_reports_kfold = pd.DataFrame(all_best_model_reports)
df_all_class_reports_kfold.to_excel('all_class_reports_kfold.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[41], line 2
#       1 df_all_class_reports_kfold = pd.DataFrame(all_best_model_reports)
# ----> 2 df_all_class_reports_kfold.to_excel('all_class_reports_kfold.xlsx', index=False)
#
# File c:\Users\Deri\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\Deri\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:2417, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2404 from pandas.io.formats.excel import ExcelFormatter
#    2406 formatter = ExcelFormatter(
#    2407     df,
#    2408     na_rep=na_rep,
#    (...)
#    2415     inf_rep=inf_rep,
#    2416 )
# -> 2417 formatter.write(
#    2418     excel_writer,
#    2419     sheet_name=sheet_name,
#    2420     startrow=startrow,
#    2421     startcol=startcol,
#    2422     freeze_panes=freeze_panes,
#    2423     engine=engine,
#    2424     storage_options=storage_options,
#    2425     engine_kwargs=engine_kwargs,
#    2426 )
#
# File c:\Users\Deri\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\excel.py:943, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     941     need_save = False
#     942 else:
# --> 943     writer = ExcelWriter(
#     944         writer,
#     945         engine=engine,
#     946         storage_options=storage_options,
#     947         engine_kwargs=engine_kwargs,
#     948     )
#     949     need_save = True
#     951 try:
#
# File c:\Users\Deri\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_xlsxwriter.py:204, in XlsxWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     201 if mode == "a":
#     202     raise ValueError("Append mode is not supported with xlsxwriter!")
# --> 204 super().__init__(
#     205     path,
#     206     engine=engine,
#     207     date_format=date_format,
#     208     datetime_format=datetime_format,
#     209     mode=mode,
#     210     storage_options=storage_options,
#     211     if_sheet_exists=if_sheet_exists,
#     212     engine_kwargs=engine_kwargs,
#     213 )
#     215 try:
#     216     self._book = Workbook(self._handles.handle, **engine_kwargs)
#
# File c:\Users\Deri\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:1246, in ExcelWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1242 self._handles = IOHandles(
#    1243     cast(IO[bytes], path), compression={"compression": None}
#    1244 )
#    1245 if not isinstance(path, ExcelWriter):
# -> 1246     self._handles = get_handle(
#    1247         path, mode, storage_options=storage_options, is_text=False
#    1248     )
#    1249 self._cur_sheet = None
#    1251 if date_format is None:
#
# File c:\Users\Deri\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# PermissionError: [Errno 13] Permission denied: 'all_class_reports_kfold.xlsx'

# %%
# Misal list labelnya
labels = ['IE_bin', 'NS_bin', 'TF_bin', 'JP_bin']

# Load data validasi
# Pastikan X_val dan y_val sudah didefinisikan sebelumnya

# Load model yang sudah disimpan
svm_models = {}
for label in labels:
    svm_model = joblib.load(f'{label}_svm_best_kfold.pkl')
    svm_models[label] = svm_model

# %% [markdown]
# ## Data Tes

# %%
# Membuat dictionary untuk menyimpan laporan klasifikasi
test_reports = {
    'SVM': {},
}

for label in labels:
    # Predict dan generate report untuk SVM
    y_pred_svm = svm_models[label].predict(X_test_vec)
    report_svm = classification_report(y_test[label], y_pred_svm, output_dict=True)
    test_reports['SVM'][label] = report_svm

# %%
import pandas as pd

# Fungsi untuk mengekstrak metrik dari laporan klasifikasi
def extract_metrics(report):
    metrics = {
        'precision': report['weighted avg']['precision'],
        'recall': report['weighted avg']['recall'],
        'f1-score': report['weighted avg']['f1-score'],
        'accuracy': report['accuracy']
    }
    return metrics

# Menyusun hasil evaluasi dalam DataFrame
comparison_list = []

for model_name, model_reports in test_reports.items():
    for label, report in model_reports.items():
        metrics = extract_metrics(report)
        metrics.update({'Model': model_name, 'Label': label})
        comparison_list.append(metrics)

# Konversi list of dictionaries menjadi DataFrame
comparison_df = pd.DataFrame(comparison_list)

# Pivot table untuk format tampilan yang lebih rapi
comparison_table = comparison_df.pivot(index='Label', columns='Model', values=['precision', 'recall', 'f1-score', 'accuracy'])

# Flatten MultiIndex columns
comparison_table.columns = ['_'.join(col).strip() for col in comparison_table.columns.values]

# Reset index
comparison_table = comparison_table.reset_index()

# Membulatkan angka desimal
comparison_table = comparison_table.round(3)

# Menambahkan judul
print("\n=== Akurasi Data Test ===\n")

# Menggunakan pandas Styler untuk menambahkan gridlines
styled_table = comparison_table.style.set_table_styles(
    [
        {'selector': 'th', 'props': [('border', '1px solid black'), ('padding', '5px'), ('font-size', '12pt')]},
        {'selector': 'td', 'props': [('border', '1px solid black'), ('padding', '5px'), ('font-size', '10pt')]},
        {'selector': 'table', 'props': [('border-collapse', 'collapse')]},
    ]
).set_properties(**{'border': '1px solid black', 'padding': '5px'})

# Menambahkan warna latar belakang (opsional)
styled_table = styled_table.background_gradient(cmap='YlGnBu')

# Tampilkan tabel dengan styling di Jupyter Notebook atau lingkungan yang mendukung HTML
styled_table
# Out:
# === Akurasi Data Test ===
# <style type="text/css">
# #T_81a8e th {
#   border: 1px solid black;
#   padding: 5px;
#   font-size: 12pt;
# }
# #T_81a8e td {
#   border: 1px solid black;
#   padding: 5px;
#   font-size: 10pt;
# }
# #T_81a8e table {
#   border-collapse: collapse;
# }
# #T_81a8e_row0_col0, #T_81a8e_row1_col0, #T_81a8e_row2_col0, #T_81a8e_row3_col0 {
#   border: 1px solid black;
#   padding: 5px;
# }
# #T_81a8e_row0_col1 {
#   border: 1px solid black;
#   padding: 5px;
#   background-color: #225ca7;
#   color: #f1f1f1;
# }
# #T_81a8e_row0_col2, #T_81a8e_row0_col3, #T_81a8e_row0_col4, #T_81a8e_row1_col1 {
#   border: 1px solid black;
#   padding: 5px;
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_81a8e_row1_col2, #T_81a8e_row1_col4 {
#   border: 1px solid black;
#   padding: 5px;
#   background-color: #97d6b9;
#   color: #000000;
# }
# #T_81a8e_row1_col3 {
#   border: 1px solid black;
#   padding: 5px;
#   background-color: #48b9c3;
#   color: #f1f1f1;
# }
# #T_81a8e_row2_col1, #T_81a8e_row2_col2, #T_81a8e_row2_col3, #T_81a8e_row2_col4 {
#   border: 1px solid black;
#   padding: 5px;
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_81a8e_row3_col1 {
#   border: 1px solid black;
#   padding: 5px;
#   background-color: #1e86bb;
#   color: #f1f1f1;
# }
# #T_81a8e_row3_col2, #T_81a8e_row3_col4 {
#   border: 1px solid black;
#   padding: 5px;
#   background-color: #1e8abd;
#   color: #f1f1f1;
# }
# #T_81a8e_row3_col3 {
#   border: 1px solid black;
#   padding: 5px;
#   background-color: #3db2c4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_81a8e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81a8e_level0_col0" class="col_heading level0 col0" >Label</th>
#       <th id="T_81a8e_level0_col1" class="col_heading level0 col1" >precision_SVM</th>
#       <th id="T_81a8e_level0_col2" class="col_heading level0 col2" >recall_SVM</th>
#       <th id="T_81a8e_level0_col3" class="col_heading level0 col3" >f1-score_SVM</th>
#       <th id="T_81a8e_level0_col4" class="col_heading level0 col4" >accuracy_SVM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81a8e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_81a8e_row0_col0" class="data row0 col0" >IE_bin</td>
#       <td id="T_81a8e_row0_col1" class="data row0 col1" >0.552000</td>
#       <td id="T_81a8e_row0_col2" class="data row0 col2" >0.608000</td>
#       <td id="T_81a8e_row0_col3" class="data row0 col3" >0.567000</td>
#       <td id="T_81a8e_row0_col4" class="data row0 col4" >0.608000</td>
#     </tr>
#     <tr>
#       <th id="T_81a8e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_81a8e_row1_col0" class="data row1 col0" >JP_bin</td>
#       <td id="T_81a8e_row1_col1" class="data row1 col1" >0.561000</td>
#       <td id="T_81a8e_row1_col2" class="data row1 col2" >0.556000</td>
#       <td id="T_81a8e_row1_col3" class="data row1 col3" >0.546000</td>
#       <td id="T_81a8e_row1_col4" class="data row1 col4" >0.556000</td>
#     </tr>
#     <tr>
#       <th id="T_81a8e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_81a8e_row2_col0" class="data row2 col0" >NS_bin</td>
#       <td id="T_81a8e_row2_col1" class="data row2 col1" >0.524000</td>
#       <td id="T_81a8e_row2_col2" class="data row2 col2" >0.530000</td>
#       <td id="T_81a8e_row2_col3" class="data row2 col3" >0.526000</td>
#       <td id="T_81a8e_row2_col4" class="data row2 col4" >0.530000</td>
#     </tr>
#     <tr>
#       <th id="T_81a8e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_81a8e_row3_col0" class="data row3 col0" >TF_bin</td>
#       <td id="T_81a8e_row3_col1" class="data row3 col1" >0.548000</td>
#       <td id="T_81a8e_row3_col2" class="data row3 col2" >0.580000</td>
#       <td id="T_81a8e_row3_col3" class="data row3 col3" >0.547000</td>
#       <td id="T_81a8e_row3_col4" class="data row3 col4" >0.580000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Menyimpan hasil evaluasi per label dan per kelas (0 & 1)
all_class_reports = []

for label in labels:
    # Prediksi pada data test
    y_pred = svm_models[label].predict(X_test_vec)

    # Ambil classification report
    report = classification_report(y_test[label], y_pred, output_dict=True)

    # Cek apakah kedua kelas ada
    for kelas in ['0', '1']:
        if kelas in report:
            precision = report[kelas]['precision']
            recall = report[kelas]['recall']
            f1_score = report[kelas]['f1-score']
        else:
            precision = recall = f1_score = 0.0  # Jika tidak ditemukan

        # Tambahkan ke list
        all_class_reports.append({
            'Label': label,
            'Kelas': kelas,
            'Precision': round(precision, 3),
            'Recall': round(recall, 3),
            'F1_Score': round(f1_score, 3),
            'Accuracy': round(report['accuracy'], 3)
        })

# Buat dataframe
df_all_class_reports_test = pd.DataFrame(all_class_reports)

# Tampilkan di terminal
print("=== Laporan Evaluasi Tiap Label dan Kelas ===")
print(df_all_class_reports_test)
# Out:
# === Laporan Evaluasi Tiap Label dan Kelas ===
#     Label Kelas  Precision  Recall  F1_Score  Accuracy
# 0  IE_bin     0      0.670   0.823     0.739     0.608
# 1  IE_bin     1      0.308   0.163     0.213     0.608
# 2  NS_bin     0      0.425   0.393     0.408     0.530
# 3  NS_bin     1      0.594   0.626     0.610     0.530
# 4  TF_bin     0      0.621   0.799     0.699     0.580
# 5  TF_bin     1      0.435   0.241     0.310     0.580
# 6  JP_bin     0      0.543   0.700     0.612     0.556
# 7  JP_bin     1      0.578   0.411     0.481     0.556

# %%
df_all_class_reports_test.to_excel('report_before_augment.xlsx',index=False)
