# %%
import json
import pandas as pd
import random
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
import joblib
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV, StratifiedKFold

# %%
df = pd.read_csv('Data_Train.csv')
df.head()
# Out:
#                                            full_text     username  MBTI IE NS  \
# 0  masih about my wedding makeup kali ini makeup ...  DylanSahara  ENFJ  E  N
# 1  terima kasih kepada bapak prabowo subianto yan...  DylanSahara  ENFJ  E  N
# 2                          halo calon suami hahahaha  DylanSahara  ENFJ  E  N
# 3  muka dicoretcoret pakai kostum kayak orang gil...  DylanSahara  ENFJ  E  N
# 4       saat muka masih cakep belum dicemongcemongin  DylanSahara  ENFJ  E  N
#
#   TF JP
# 0  F  J
# 1  F  J
# 2  F  J
# 3  F  J
# 4  F  J

# %%
df.shape
# Out:
# (9350, 7)

# %%
df.username.value_counts()
# Out:
# username
# DylanSahara        50
# chelseaolivia92    50
# EmilDardak         50
# cuttaryofficial    50
# elviraelph         50
#                    ..
# hanggini           50
# dionwiyoko         50
# dimsanggara        50
# irisLoco           50
# chelseaislan       50
# Name: count, Length: 187, dtype: int64

# %%
df.username.nunique()
# Out:
# 187

# %%
# Ubah label IE ke format biner
df['IE_bin'] = df['IE'].apply(lambda x: 1 if x == 'I' else 0)
df['NS_bin'] = df['NS'].apply(lambda x: 1 if x == 'N' else 0)
df['TF_bin'] = df['TF'].apply(lambda x: 1 if x == 'T' else 0)
df['JP_bin'] = df['JP'].apply(lambda x: 1 if x == 'J' else 0)

# %%
df.head()
# Out:
#                                            full_text     username  MBTI IE NS  \
# 0  masih about my wedding makeup kali ini makeup ...  DylanSahara  ENFJ  E  N
# 1  terima kasih kepada bapak prabowo subianto yan...  DylanSahara  ENFJ  E  N
# 2                          halo calon suami hahahaha  DylanSahara  ENFJ  E  N
# 3  muka dicoretcoret pakai kostum kayak orang gil...  DylanSahara  ENFJ  E  N
# 4       saat muka masih cakep belum dicemongcemongin  DylanSahara  ENFJ  E  N
#
#   TF JP  IE_bin  NS_bin  TF_bin  JP_bin
# 0  F  J       0       1       0       1
# 1  F  J       0       1       0       1
# 2  F  J       0       1       0       1
# 3  F  J       0       1       0       1
# 4  F  J       0       1       0       1

# %%
df_test = pd.read_csv('Data_Test.csv')

# %%
df_test.head()
# Out:
#                                            full_text      username  MBTI IE  \
# 0                                      lah bagaimana  bismakarisma  ISFJ  I
# 1                                       uji coba yok  bismakarisma  ISFJ  I
# 2  ngeri antusiasku bisa sampai belum tidur gini ...  bismakarisma  ISFJ  I
# 3  aduh ini badut romantis yang selalu romantis l...  bismakarisma  ISFJ  I
# 4                                   lop yu dari sagi  bismakarisma  ISFJ  I
#
#   NS TF JP
# 0  S  F  J
# 1  S  F  J
# 2  S  F  J
# 3  S  F  J
# 4  S  F  J

# %%
df_test.shape
# Out:
# (2300, 7)

# %%
df_test.username.value_counts()
# Out:
# username
# bismakarisma       50
# AndovidaLopez      50
# kikysaputrii       50
# nessiejudge        50
# ekagustiwana       50
# CoachJustinL       50
# ernestprakasa      50
# Arie_Kriting       50
# suryainsomnia      50
# ArnoldPoernomo     50
# TretanMuslim       50
# LunaMaya26         50
# brisiajodie96      50
# jokowi             50
# felixsiauw         50
# tirta_cipeng       50
# aniesbaswedan      50
# erickthohir        50
# tulusm             50
# A_FionyJKT48       50
# _shanindira        50
# RFritzy_JKT48      50
# Dodit_Mulyanto     50
# danillajpr         50
# bobbynasution_     50
# amandamanopo       50
# yukikato           50
# alfiealfandy       50
# alicesofieNORIN    50
# omeshomesh         50
# wikanarif          50
# TitiRadjoPdmaja    50
# shenacinnamon      50
# ronniesianturi     50
# itsPrisia          50
# annekejd           50
# auliasarah69       50
# ayukhadijahazha    50
# ralineshah         50
# Bellaudyaa         50
# jonasrivanno       50
# kvinjulio          50
# kinaryosih_03      50
# desyratnasari      50
# Donny_Alamsyah     50
# uusbiasaaja        50
# Name: count, dtype: int64

# %%
df_test.username.nunique()
# Out:
# 46

# %%
# Ubah label IE ke format biner
df_test['IE_bin'] = df_test['IE'].apply(lambda x: 1 if x == 'I' else 0)
df_test['NS_bin'] = df_test['NS'].apply(lambda x: 1 if x == 'N' else 0)
df_test['TF_bin'] = df_test['TF'].apply(lambda x: 1 if x == 'T' else 0)
df_test['JP_bin'] = df_test['JP'].apply(lambda x: 1 if x == 'J' else 0)

# %%
df_test.head()
# Out:
#                                            full_text      username  MBTI IE  \
# 0                                      lah bagaimana  bismakarisma  ISFJ  I
# 1                                       uji coba yok  bismakarisma  ISFJ  I
# 2  ngeri antusiasku bisa sampai belum tidur gini ...  bismakarisma  ISFJ  I
# 3  aduh ini badut romantis yang selalu romantis l...  bismakarisma  ISFJ  I
# 4                                   lop yu dari sagi  bismakarisma  ISFJ  I
#
#   NS TF JP  IE_bin  NS_bin  TF_bin  JP_bin
# 0  S  F  J       1       0       0       1
# 1  S  F  J       1       0       0       1
# 2  S  F  J       1       0       0       1
# 3  S  F  J       1       0       0       1
# 4  S  F  J       1       0       0       1

# %%
X_test, y_test = df_test["full_text"], df_test[["IE_bin", "NS_bin", "TF_bin", "JP_bin"]]

X_test_vec = vectorizer.transform(X_test)

# %%
# Membuat TF-IDF vectorizer dengan batas 1000 fitur
texts = df['full_text']
vectorizer = TfidfVectorizer(max_features=1000)
X = vectorizer.fit_transform(texts)

# Label
y = df[['IE_bin', 'NS_bin', 'TF_bin', 'JP_bin']]

# %%
# Inisialisasi K-Fold
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
all_class_reports = []
# Menyimpan model terbaik dari setiap label
best_models = {}
label_list = ['IE_bin', 'NS_bin', 'TF_bin', 'JP_bin']
all_best_model_reports = []

for label in label_list:
    print(f"\nTraining SVM untuk label {label} dengan K-Fold...")
    best_score = 0
    best_model = None
    best_report = None
    fold_num = 1

    for train_index, val_index in kf.split(X, y[label]):
        X_train_fold, X_val_fold = X[train_index], X[val_index]
        y_train_fold = y[label].iloc[train_index]
        y_val_fold = y[label].iloc[val_index]

        model = SVC(C=10, gamma='scale', kernel='rbf')
        model.fit(X_train_fold, y_train_fold)

        y_pred = model.predict(X_val_fold)
        report = classification_report(y_val_fold, y_pred, output_dict=True)
        f1 = report['weighted avg']['f1-score']
        print(f"Fold {fold_num} - F1 Score: {f1:.4f}")
        fold_num += 1

        if f1 > best_score:
            best_score = f1
            best_model = model
            best_report = report

    # Simpan model terbaik
    best_models[label] = best_model
    joblib.dump(best_model, f'{label}_svm_best_kfold.pkl')

    # Simpan laporan performa
    for kelas in ['0', '1']:
        if kelas in best_report:
            precision = best_report[kelas]['precision']
            recall = best_report[kelas]['recall']
            f1_score_kelas = best_report[kelas]['f1-score']
        else:
            precision = recall = f1_score_kelas = 0.0

        all_best_model_reports.append({
            'Label': label,
            'Kelas': kelas,
            'Precision': round(precision, 3),
            'Recall': round(recall, 3),
            'F1_Score': round(f1_score_kelas, 3),
            'Accuracy': round(best_report['accuracy'], 3)
        })
# Out:
# Training SVM untuk label IE_bin dengan K-Fold...
# Fold 1 - F1 Score: 0.6238
# Fold 2 - F1 Score: 0.6121
# Fold 3 - F1 Score: 0.6188
# Fold 4 - F1 Score: 0.6418
# Fold 5 - F1 Score: 0.6393
#
# Training SVM untuk label NS_bin dengan K-Fold...
# Fold 1 - F1 Score: 0.6275
# Fold 2 - F1 Score: 0.6065
# Fold 3 - F1 Score: 0.5900
# Fold 4 - F1 Score: 0.5961
# Fold 5 - F1 Score: 0.6041
#
# Training SVM untuk label TF_bin dengan K-Fold...
# Fold 1 - F1 Score: 0.6771
# Fold 2 - F1 Score: 0.6694
# Fold 3 - F1 Score: 0.6657
# Fold 4 - F1 Score: 0.6587
# Fold 5 - F1 Score: 0.6702
#
# Training SVM untuk label JP_bin dengan K-Fold...
# Fold 1 - F1 Score: 0.6148
# Fold 2 - F1 Score: 0.6207
# Fold 3 - F1 Score: 0.6136
# Fold 4 - F1 Score: 0.6161
# Fold 5 - F1 Score: 0.6157

# %%
df_all_class_reports_kfold = pd.DataFrame(all_best_model_reports)
df_all_class_reports_kfold.to_excel('all_class_reports_kfold.xlsx', index=False)

# %%
# Misal list labelnya
labels = ['IE_bin', 'NS_bin', 'TF_bin', 'JP_bin']

# Load data validasi
# Pastikan X_val dan y_val sudah didefinisikan sebelumnya

# Load model yang sudah disimpan
svm_models = {}
for label in labels:
    svm_model = joblib.load(f'{label}_svm_best_kfold.pkl')
    svm_models[label] = svm_model

# %% [markdown]
# ## Data Tes

# %%
# Membuat dictionary untuk menyimpan laporan klasifikasi
test_reports = {
    'SVM': {},
}

for label in labels:
    # Predict dan generate report untuk SVM
    y_pred_svm = svm_models[label].predict(X_test_vec)
    report_svm = classification_report(y_test[label], y_pred_svm, output_dict=True)
    test_reports['SVM'][label] = report_svm

# %%
import pandas as pd

# Fungsi untuk mengekstrak metrik dari laporan klasifikasi
def extract_metrics(report):
    metrics = {
        'precision': report['weighted avg']['precision'],
        'recall': report['weighted avg']['recall'],
        'f1-score': report['weighted avg']['f1-score'],
        'accuracy': report['accuracy']
    }
    return metrics

# Menyusun hasil evaluasi dalam DataFrame
comparison_list = []

for model_name, model_reports in test_reports.items():
    for label, report in model_reports.items():
        metrics = extract_metrics(report)
        metrics.update({'Model': model_name, 'Label': label})
        comparison_list.append(metrics)

# Konversi list of dictionaries menjadi DataFrame
comparison_df = pd.DataFrame(comparison_list)

# Pivot table untuk format tampilan yang lebih rapi
comparison_table = comparison_df.pivot(index='Label', columns='Model', values=['precision', 'recall', 'f1-score', 'accuracy'])

# Flatten MultiIndex columns
comparison_table.columns = ['_'.join(col).strip() for col in comparison_table.columns.values]

# Reset index
comparison_table = comparison_table.reset_index()

# Membulatkan angka desimal
comparison_table = comparison_table.round(3)

# Menambahkan judul
print("\n=== Akurasi Data Test ===\n")

# Menggunakan pandas Styler untuk menambahkan gridlines
styled_table = comparison_table.style.set_table_styles(
    [
        {'selector': 'th', 'props': [('border', '1px solid black'), ('padding', '5px'), ('font-size', '12pt')]},
        {'selector': 'td', 'props': [('border', '1px solid black'), ('padding', '5px'), ('font-size', '10pt')]},
        {'selector': 'table', 'props': [('border-collapse', 'collapse')]},
    ]
).set_properties(**{'border': '1px solid black', 'padding': '5px'})

# Menambahkan warna latar belakang (opsional)
styled_table = styled_table.background_gradient(cmap='YlGnBu')

# Tampilkan tabel dengan styling di Jupyter Notebook atau lingkungan yang mendukung HTML
styled_table
# Out:
# === Akurasi Data Test ===
# <style type="text/css">
# #T_e75bd th {
#   border: 1px solid black;
#   padding: 5px;
#   font-size: 12pt;
# }
# #T_e75bd td {
#   border: 1px solid black;
#   padding: 5px;
#   font-size: 10pt;
# }
# #T_e75bd table {
#   border-collapse: collapse;
# }
# #T_e75bd_row0_col0, #T_e75bd_row1_col0, #T_e75bd_row2_col0, #T_e75bd_row3_col0 {
#   border: 1px solid black;
#   padding: 5px;
# }
# #T_e75bd_row0_col1 {
#   border: 1px solid black;
#   padding: 5px;
#   background-color: #31a5c2;
#   color: #f1f1f1;
# }
# #T_e75bd_row0_col2, #T_e75bd_row0_col3, #T_e75bd_row0_col4, #T_e75bd_row1_col1 {
#   border: 1px solid black;
#   padding: 5px;
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_e75bd_row1_col2, #T_e75bd_row1_col4, #T_e75bd_row3_col2, #T_e75bd_row3_col4 {
#   border: 1px solid black;
#   padding: 5px;
#   background-color: #3eb3c4;
#   color: #f1f1f1;
# }
# #T_e75bd_row1_col3 {
#   border: 1px solid black;
#   padding: 5px;
#   background-color: #216aad;
#   color: #f1f1f1;
# }
# #T_e75bd_row2_col1, #T_e75bd_row2_col2, #T_e75bd_row2_col3, #T_e75bd_row2_col4 {
#   border: 1px solid black;
#   padding: 5px;
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_e75bd_row3_col1 {
#   border: 1px solid black;
#   padding: 5px;
#   background-color: #d0edb3;
#   color: #000000;
# }
# #T_e75bd_row3_col3 {
#   border: 1px solid black;
#   padding: 5px;
#   background-color: #b7e3b6;
#   color: #000000;
# }
# </style>
# <table id="T_e75bd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e75bd_level0_col0" class="col_heading level0 col0" >Label</th>
#       <th id="T_e75bd_level0_col1" class="col_heading level0 col1" >precision_SVM</th>
#       <th id="T_e75bd_level0_col2" class="col_heading level0 col2" >recall_SVM</th>
#       <th id="T_e75bd_level0_col3" class="col_heading level0 col3" >f1-score_SVM</th>
#       <th id="T_e75bd_level0_col4" class="col_heading level0 col4" >accuracy_SVM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e75bd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e75bd_row0_col0" class="data row0 col0" >IE_bin</td>
#       <td id="T_e75bd_row0_col1" class="data row0 col1" >0.561000</td>
#       <td id="T_e75bd_row0_col2" class="data row0 col2" >0.604000</td>
#       <td id="T_e75bd_row0_col3" class="data row0 col3" >0.574000</td>
#       <td id="T_e75bd_row0_col4" class="data row0 col4" >0.604000</td>
#     </tr>
#     <tr>
#       <th id="T_e75bd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e75bd_row1_col0" class="data row1 col0" >JP_bin</td>
#       <td id="T_e75bd_row1_col1" class="data row1 col1" >0.581000</td>
#       <td id="T_e75bd_row1_col2" class="data row1 col2" >0.573000</td>
#       <td id="T_e75bd_row1_col3" class="data row1 col3" >0.564000</td>
#       <td id="T_e75bd_row1_col4" class="data row1 col4" >0.573000</td>
#     </tr>
#     <tr>
#       <th id="T_e75bd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e75bd_row2_col0" class="data row2 col0" >NS_bin</td>
#       <td id="T_e75bd_row2_col1" class="data row2 col1" >0.536000</td>
#       <td id="T_e75bd_row2_col2" class="data row2 col2" >0.541000</td>
#       <td id="T_e75bd_row2_col3" class="data row2 col3" >0.538000</td>
#       <td id="T_e75bd_row2_col4" class="data row2 col4" >0.541000</td>
#     </tr>
#     <tr>
#       <th id="T_e75bd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e75bd_row3_col0" class="data row3 col0" >TF_bin</td>
#       <td id="T_e75bd_row3_col1" class="data row3 col1" >0.546000</td>
#       <td id="T_e75bd_row3_col2" class="data row3 col2" >0.573000</td>
#       <td id="T_e75bd_row3_col3" class="data row3 col3" >0.548000</td>
#       <td id="T_e75bd_row3_col4" class="data row3 col4" >0.573000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Menyimpan hasil evaluasi per label dan per kelas (0 & 1)
all_class_reports = []

for label in labels:
    # Prediksi pada data test
    y_pred = svm_models[label].predict(X_test_vec)

    # Ambil classification report
    report = classification_report(y_test[label], y_pred, output_dict=True)

    # Cek apakah kedua kelas ada
    for kelas in ['0', '1']:
        if kelas in report:
            precision = report[kelas]['precision']
            recall = report[kelas]['recall']
            f1_score = report[kelas]['f1-score']
        else:
            precision = recall = f1_score = 0.0  # Jika tidak ditemukan

        # Tambahkan ke list
        all_class_reports.append({
            'Label': label,
            'Kelas': kelas,
            'Precision': round(precision, 3),
            'Recall': round(recall, 3),
            'F1_Score': round(f1_score, 3),
            'Accuracy': round(report['accuracy'], 3)
        })

# Buat dataframe
df_all_class_reports_test = pd.DataFrame(all_class_reports)

# Tampilkan di terminal
print("=== Laporan Evaluasi Tiap Label dan Kelas ===")
print(df_all_class_reports_test)
# Out:
# === Laporan Evaluasi Tiap Label dan Kelas ===
#     Label Kelas  Precision  Recall  F1_Score  Accuracy
# 0  IE_bin     0      0.674   0.797     0.731     0.604
# 1  IE_bin     1      0.328   0.204     0.251     0.604
# 2  NS_bin     0      0.440   0.408     0.424     0.541
# 3  NS_bin     1      0.604   0.635     0.619     0.541
# 4  TF_bin     0      0.621   0.765     0.686     0.573
# 5  TF_bin     1      0.429   0.274     0.335     0.573
# 6  JP_bin     0      0.557   0.723     0.629     0.573
# 7  JP_bin     1      0.605   0.424     0.499     0.573

# %%
df_all_class_reports_test.to_excel('report_before_augment.xlsx',index=False)
